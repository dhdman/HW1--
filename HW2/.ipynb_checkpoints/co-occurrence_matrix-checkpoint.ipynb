# %%
import os
import jieba
import numpy as np
from collections import Counter
# pip install gensim
from gensim.corpora import Dictionary
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %% [markdown]
# ### 讀入stopwords

# %%
stopwords = []
jieba.set_dictionary('./jieba_data/dict.txt.big')
jieba.load_userdict('./jieba_data/userdict.txt')

with open('./jieba_data/stopwords.txt', 'r', encoding='UTF-8') as file:
    for data in file.readlines():
        data = data.strip()
        stopwords.append(data)
# Out:
# Building prefix dict from /Users/alexis/Documents/GitHub/HW1--data-mining_bak/HW2/jieba_data/dict.txt.big ...
# Loading model from cache /var/folders/y9/vfmh1hx93jj2rp98mgt85dl00000gn/T/jieba.ub3af8d1fe5443e291930f157fa54cb87.cache
# Loading model cost 1.111 seconds.
# Prefix dict has been built succesfully.

# %%
def getTokens(text):
    tokens = []
    if len(text) > 0:
        segments = jieba.cut(text,cut_all=False)
        for t in segments:
            t = t.strip()
            if not t in stopwords:
                tokens.append(t)
    return tokens

# %%
def getText(filename):
    with open(filename,'r') as file:
        lines = file.readlines()
        
    news_title = lines[2]
    news_body = lines[3]
    text = news_title + news_body
    return(text)

# %% [markdown]
# ### 取出全部文件(180個)的內容做斷詞

# %%
text = ''
dir_path = './ctee_TMC'
for file in os.listdir(dir_path):
    file_path = os.path.join(dir_path,file)
    if os.path.isfile(file_path) and not file.startswith('.'):
        text = text + getText(file_path)

tokens = getTokens(text)

# %% [markdown]
# ### 共有約2萬個詞

# %%
print(len(tokens))
# Out:
# 17595

# %% [markdown]
# ### 共有約5000個不重複詞

# %%
counter = Counter(tokens)
print(len(counter))
# Out:
# 5065

# %% [markdown]
# ### 取出詞頻最高前500個詞

# %%
top_tokens_tuple = counter.most_common(500)
all_tokens = []
for t in top_tokens_tuple:
    all_tokens.append(t[0])

print(all_tokens)
# Out:
# ['元', '億元', '％', '奈米', '營收', '外資', '製程', '市場', ',', '晶圓', '台股', '法人', '成長', '去年', '科技', '股價', '代工', '10', '脈動', '股利', '預期', '(', ')', '現金', '龍頭', '半導體', '約', '2330', '點', '買超', '新高', '後', '新', '第一季', '-', '台灣', '高', '晶片', '市值', '蘋果', '中', '指出', '影響', '大', '產業', '技術', '12', '達', '先進', '～', '可望', '客戶', '上漲', '仍', '公司', '每股', '前', '設計', '持續', '11', '昨', '營運', '第四季', '全球', '證券', '投資', '獲利', '產能', '台積', '手機', '董事長', '訂單', '預估', '台幣', '歷史', '指數', '合併', '股', '處理器', '說', '已', '大立光', '更', '上', '張忠謀', '未來', '減少', '2019', '明年', '董事會', '廠', '財經', '毛利率', '億美元', '2018', '逾', '個股', '展望', '帶動', '包括', '季', '美元', '發展', '全年', '不', '增加', '業績', '表現', '聯發科', '需求', '受惠', '2020', '下', '產品', '出貨', '兆元', 'iPhone', '事件', '行情', '漲幅', '5G', '創新', '第二季', '創意', '配發', '量產', '人', '盤中', '大陸', '季減', '再', '看好', '稅後', '震盪', '營業', '占', '優於', '企業', '淨利', '紀錄', '16', '英特爾', '評等', '運算', '發放', '加上', '新台幣', '去年同期', '權值', '資金', '營收達', '動能', '好', '比特', '鴻海', '超過', '金額', '利益', '今', '張', '核准', '南京', '法說', 'AI', '利率', '上半年', '大漲', '美國', '吋', '權證', '看', '美', '智慧型', '國際', '機會', '員工', '資本', '20', '目標', '分析師', '重要', '成', '最', '符合', '最新', 'ASIC', '計畫', '公布', '近期', '提供', '報導', '相關', '18', '圈', '樂觀', '貢獻', '下滑', '要聞', '推升', '預計', '13', '布局', '300', '均', '盈餘', '矽智財', 'ADR', '17', '首季', '人工智慧', '智慧', '下半年', '三星', '第三季', '買盤', '放量', '月營', '平均', '創', '一度', '財測', '供應鏈', '鏡頭', '股東', '今日', '財報', '下修', '強勁', '大廠', '賣', '賣超', '來看', '超微', '進一步', '銷售', '面臨', '公告', '收在', '挖礦', '導致', '淡季', '近', '三大', '交易日', '領先', '政策', '15', '低', 'IC', '上市', '股市', '第一', '排名', '順利', '日前', '業界', '提升', '21', '搶', '件', '開發', '劉德音', '生產', '波段', '投資人', '百分點', '今早', '磋商', '28', '同步', '財務', '增', '卻', '年度', '之間', '華為', '南科', '19', '2017', '連續', '累計', '單季', '亦', '目標價', '衝擊', '申請', '電子', '大學', '世界', '一年', '執行長', '出', '傳出', '利空', '14', '留意', '股東會', '庫存', '仍將', '推出', '支援', '收', '開', '幣', '來到', '台', '考量', '整體', '反彈', '採用', '兆', '說明會', '兌', '創下', '投片', '投顧', '000', '受', '開出', '銀行', '領域', '年增', '多頭', '升息', '小跌', '回補', '報廢', '經濟', '魏哲家', '介於', '將在', '走揚', '突破', '里昂', '機構', '情況', '陳', '壓力', '調升', '履歷', '向上', '賣壓', '建廠', '試產', '穩定', '將於', '正式', '規劃', 'K', '普通股', '每季', '配息', '很', '先前', '倍', '時', '支撐', '衰退', '年減', '保守', '高通', 'EUV', 'Q4', '美元匯率', '超越', '估計', '合計', '激勵', '季營收', '~', '達成', '挑戰', '/', '賺', '歸屬', '母公司', '5.5', '早盤', '拿下', '再創新高', '成熟', '股權', '升值', '光', '希望', '貿易戰', '工作', 'EPS', '繪圖', '貨幣', '大關', '有望', '關注', '大立', '來自', '凱升', '關鍵', '平台', '+', '官股', '輝達', '高點', '億', '薪酬', '方式', '一路', '再創', '基金', '大盤', '青年', '貿易', 'M31', '法', '長線', '推測', 'HPC', '殖', '車用', '區間', '觀察', '利用率', 'A1', '比重', '裝置', '指標', '加權指數', '共', '超', '高達', '美股', '啟動', '預測', '提出', '百大', '之上', '電腦病毒', '高階', 'AMD', '同期', '降評', '跌破', '摩根士丹利', '競爭', 'A3', '合作', '專利', '量', '走勢', '價值', '股息', '估', '透過', '交易', '率', '匯率', '時間', '擔憂', '跳空', '德意志', '本周', 'A12', '新低', '提高', '力道', '顯示', '服務', '30', '拚', '世代', '系統', '年線', '低於', '基本面', '環球', '題材', '計劃', '人力', '新鮮', '104', '能力', '小漲', '總', '動態', '興建', '風險', '上周五', '改寫', '退休', '預算', '萬元', '支持', '技術論壇', '登場', '除息', '10%', '成交量', '工業', '科技股', '漲停', '22']

# %% [markdown]
# ### 過濾掉沒有在top 500裡的詞

# %%
def filterTokens(tokens):
    global all_tokens
    filtered_tokens = []
    for t in tokens:
        if t in all_tokens:
            filtered_tokens.append(t)
    return filtered_tokens

# %%
doc_tokens = []
dir_path = './ctee_TMC'
for file in os.listdir(dir_path):
    file_path = os.path.join(dir_path,file)
    if os.path.isfile(file_path) and not file.startswith('.'):
        wanted_tokens = []
        text = getText(file_path)
        tokens = getTokens(text)
        tokens2 = filterTokens(tokens)
        doc_tokens.append(tokens2)

# %% [markdown]
# ### 稀疏矩陣

# %%
sparse_matrix = []

dir_path = './ctee_TMC'
for file in os.listdir(dir_path):
    file_path = os.path.join(dir_path,file)
    if os.path.isfile(file_path) and not file.startswith('.'):
        text = getText(file_path)
        tokens = getTokens(text)
        doc_to_term = []
        for t in all_tokens:
            if t in tokens:
                doc_to_term.append(1)
            else:
                doc_to_term.append(0)
        sparse_matrix.append(doc_to_term)

# %% [markdown]
# ### 共現矩陣

# %%
def co_occurrence_matrix(ls):
    global matrix
    length = len(ls)
    for i in range(length):
        for j in range(length):
            if i != j:
                matrix[[ls[i]], [ls[j]]] += 1

# %%
dimension = len(all_tokens)
matrix = np.matrix([[0] * dimension] * dimension)

dt = Dictionary(doc_tokens).token2id
doc_token_ids = [[dt[word] for word in words] for words in doc_tokens]

for ids in doc_token_ids:
    co_occurrence_matrix(ids)

# %%
print(dt)
# Out:
# {'28': 0, '前': 1, '大陸': 2, '奈米': 3, '政策': 4, '營業': 5, '相關': 6, '財經': 7, '-': 8, '10': 9, '15': 10, '17': 11, '18': 12, '20': 13, '2019': 14, '2020': 15, '5G': 16, 'AI': 17, 'HPC': 18, 'iPhone': 19, '上半年': 20, '下修': 21, '下半年': 22, '下滑': 23, '人工智慧': 24, '仍': 25, '低': 26, '來到': 27, '保守': 28, '倍': 29, '元': 30, '先前': 31, '全年': 32, '分析師': 33, '利率': 34, '利用率': 35, '加上': 36, '區間': 37, '反彈': 38, '受惠': 39, '可望': 40, '台': 41, '同步': 42, '圈': 43, '增': 44, '外資': 45, '季': 46, '季減': 47, '客戶': 48, '年減': 49, '強勁': 50, '後': 51, '成': 52, '投資': 53, '指出': 54, '推測': 55, '支撐': 56, '整體': 57, '新': 58, '時': 59, '智慧': 60, '樂觀': 61, '殖': 62, '毛利率': 63, '法': 64, '法說': 65, '減少': 66, '營收': 67, '現金': 68, '產能': 69, '發放': 70, '目標': 71, '約': 72, '美元': 73, '考量': 74, '股價': 75, '股利': 76, '衰退': 77, '製程': 78, '觀察': 79, '評等': 80, '說': 81, '證券': 82, '財務': 83, '貢獻': 84, '超過': 85, '車用': 86, '運算': 87, '重要': 88, '長線': 89, '需求': 90, '預期': 91, '首季': 92, '％': 93, '～': 94, 'EUV': 95, '三星': 96, '代工': 97, '先進': 98, '卻': 99, '台積': 100, '大廠': 101, '手機': 102, '技術': 103, '採用': 104, '晶圓': 105, '晶片': 106, '最': 107, '科技': 108, '脈動': 109, '蘋果': 110, '訂單': 111, '高通': 112, '龍頭': 113, ',': 114, 'Q4': 115, '下': 116, '之間': 117, '億美元': 118, '兆': 119, '兌': 120, '創下': 121, '創新': 122, '台幣': 123, '年度': 124, '成長': 125, '新台幣': 126, '新高': 127, '歷史': 128, '法人': 129, '第三季': 130, '第四季': 131, '美元匯率': 132, '說明會': 133, '預估': 134, '高': 135, 'A1': 136, 'IC': 137, '不': 138, '估計': 139, '占': 140, '已': 141, '投片': 142, '比重': 143, '華為': 144, '要聞': 145, '設計': 146, '超越': 147, '金額': 148, '(': 149, ')': 150, '2018': 151, '2330': 152, '億元': 153, '去年同期': 154, '合併': 155, '增加': 156, '影響': 157, '持續': 158, '產品': 159, '第二季': 160, '裝置': 161, '逾': 162, '11': 163, '12': 164, '上市': 165, '上漲': 166, '個股': 167