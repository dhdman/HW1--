# %%
import os
import jieba
import numpy as np
from collections import Counter
# pip install gensim
from gensim.corpora import Dictionary
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %% [markdown]
# ### 讀入stopwords

# %%
stopwords = []
jieba.set_dictionary('./jieba_data/dict.txt.big')
jieba.load_userdict('./jieba_data/userdict.txt')

with open('./jieba_data/stopwords.txt', 'r', encoding='UTF-8') as file:
    for data in file.readlines():
        data = data.strip()
        stopwords.append(data)
# Out:
# Building prefix dict from C:\Users\鄒峻安\Desktop\github project\HW1--data-mining\HW2\jieba_data\dict.txt.big ...
# Loading model from cache C:\Users\鄒峻安\AppData\Local\Temp\jieba.uea1b80d53a35cd1eaa4d428049c7a876.cache
# Loading model cost 1.284 seconds.
# Prefix dict has been built succesfully.

# %%
def getTokens(text):
    tokens = []
    if len(text) > 0:
        segments = jieba.cut(text,cut_all=False)
        for t in segments:
            t = t.strip()
            if not t in stopwords:
                tokens.append(t)
    return tokens

# %%
def getText(filename):
    with open(filename,'r', encoding='UTF-8') as file:
        lines = file.readlines()
        
    news_title = lines[2]
    news_body = lines[3]
    text = news_title + news_body
    return(text)

# %% [markdown]
# ### 取出全部文件(180個)的內容做斷詞

# %%
text = ''
dir_path = './ctee_TMC'
for file in os.listdir(dir_path):
    file_path = os.path.join(dir_path,file)
    if os.path.isfile(file_path) and not file.startswith('.'):
        text = text + getText(file_path)

tokens = getTokens(text)

# %% [markdown]
# ### 共有約2萬個詞

# %%
print(len(tokens))
# Out:
# 19702

# %% [markdown]
# ### 共有約5000個不重複詞

# %%
counter = Counter(tokens)
print(len(counter))
# Out:
# 5162

# %% [markdown]
# ### 取出詞頻最高前500個詞

# %%
top_tokens_tuple = counter.most_common(500)
all_tokens = []
for t in top_tokens_tuple:
    all_tokens.append(t[0])

print(all_tokens)
# Out:
# ['|', '台積電', '元', '工商時報', '億元', '台積', '％', '奈米', '營收', '日', '外資', '月', '製程', '今日焦點', '積電', '市場', ',', '晶圓', '台股', '法人', '成長', '去年', '科技', '股價', '代工', '10', '年', '脈動', '股利', '(', ')', '預期', '龍頭', '半導體', '現金', '2330', '約', '點', '買超', '新高', '後', '第一季', '台灣', '-', '高', '中', '市值', '晶片', '蘋果', '台', '影響', '指出', '產業', '達', '技術', '會', '大', '先進', '新台幣', '可望', '客戶', '～', '上漲', '公司', '仍', '每股', '持續', '設計', '營運', '昨', '第四季', '全球', '說', '前', '投資', '獲利', '證券', '產能', '董事長', '都', '手機', '歷史', '預估', '訂單', '指數', '合併', '12', '處理器', '新', '股', '張忠謀', '未來', '大立光', '董事會', '明年', '廠', '減少', '個股', '已', '億美元', '2019年', '展望', '包括', '帶動', '更', '逾', '財經', '2018年', '毛利率', '上', '不', '季', '發展', '美元', '表現', '增加', '聯發科', '全年', '受惠', '需求', '業績', '出貨', '兆元', '2020年', '產品', '下', 'iPhone', '漲幅', '行情', '即時新聞', '事件', '創新', '盤中', '第二季', '人', '5G', '創意', '配發', '營收達', '大陸', '看好', '再', '量產', '震盪', '季減', '稅後', '紀錄', '英特爾', '優於', '占', '11', '企業', '16', '營業', '淨利', '資金', '11月', '去年同期', '運算', '動能', '權值', '評等', '比特', '加上', '發放', '張', '鴻海', '核准', '南京', '超過', '金額', '利益', '機會', '好', '員工', '國際', '大漲', '美國', '資本', '智慧型', 'AI', '上半年', '吋', '權證', '美', '利率', '目標', '近期', '提供', '符合', '均', '最新', '公布', '計畫', 'ASIC', '分析師', '20', '布局', '今', '看', 'ADR', '300', '貢獻', '13', '最', '樂觀', '圈', '推升', '要聞', '預計', '相關', '下滑', '18', '盈餘', '供應鏈', '報導', '首季', '成', '人工智慧', '創', '一度', '下半年', '放量', '三星', '股東', '第三季', '今日', '買盤', '智慧', '17', '矽智財', '鏡頭', '領先', '大廠', '平均', '下修', '面臨', '交易日', '賣超', '財測', '進一步', '低', '公告', '超微', '賣', '挖礦', '淡季', '來看', '收在', '對台', '強勁', '導致', '銷售', '財報', '三大', '順利', '排名', '近', '投資人', '21', '劉德音', '提升', '生產', '業界', '上市', '日前', '政策', 'IC', '12月', '百分點', '15', '第一', '股市', '波段', '件', '磋商', '支援', '單季', '卻', '增', '2017', '台幣', '執行長', '財務', '庫存', '仍將', '衝擊', '28', '連續', '法說', '推出', '華為', '世界', '19', '股東會', '收', '14', '目標價', '亦', '之間', '同步', '搶', '一年', '出', '電子', '累計', '利空', '留意', '開發', '申請', '電將', '000', '創下', '兌', '電在', '說明會', '魏哲家', '多頭', '今早', '來到', '正式', '情況', '試產', '採用', '賣壓', '考量', '走揚', '很', '小跌', '穩定', '南科', '兆', '開出', '突破', '傳出', '年度', '幣', '受', '年增', '里昂', '普通股', '機構', '規劃', '大學', 'K', '投顧', '壓力', '反彈', '介於', '向上', '整體', '調升', '領域', '銀行', '報廢', '每季', '升息', '履歷', '億', '美元匯率', '大關', '超越', '再創新高', '升值', '高點', '拿下', '高通', '來自', '~', '成熟', '激勵', '再創', '大盤', '值', '/', '關注', '月營', '季營收', '有望', '繪圖', 'Q4', '輝達', '達成', '一路', '+', '經濟', '股權', '將於', '建廠', '先前', '挑戰', '關鍵', '平台', '貨幣', '支撐', '配息', '投片', '倍', '賺', '薪酬', '陳', '光', '希望', '保守', '5.5', '歸屬', '母公司', 'EUV', '貿易戰', '時', '估計', '官股', '合計', 'M31', '基金', '衰退', '貿易', '青年', '大立', '年減', 'EPS', '方式', '凱升', '世代', '量', '匯率', '法', '跌破', '價值', '比重', '加權指數', '30', 'HPC', '將在', '科技股', '本周', '指標', '動態', '改寫', '預算', '風險', '時間', '10%', '除息', '登場', '低於', '百大', '摩根士丹利', '同期', '區間', 'AMD', 'A1', '工業', '之上', '走勢', '退休', '支持', '環球', '題材', '啟動', '興建', '服務', '降評', '競爭', '合作', '交易', 'A12', '營收將', '觀察', '率', '上周五', '小漲', '裝置', '長線', '預測', '推測', '萬元', '新低', '早盤', '成交量', 'A3', '新鮮', '提高', '拚', '系統', '高階', '漲停', '德意志', '共', '技術論壇', '提出', '能力', '年線', '力道', '基本面', '跳空', '電腦病毒', '擔憂', '高達', '車用']

# %% [markdown]
# ### 過濾掉沒有在top 500裡的詞

# %%
def filterTokens(tokens):
    global all_tokens
    filtered_tokens = []
    for t in tokens:
        if t in all_tokens:
            filtered_tokens.append(t)
    return filtered_tokens

# %%
doc_tokens = []
dir_path = './ctee_TMC'
for file in os.listdir(dir_path):
    file_path = os.path.join(dir_path,file)
    if os.path.isfile(file_path) and not file.startswith('.'):
        wanted_tokens = []
        text = getText(file_path)
        tokens = getTokens(text)
        tokens2 = filterTokens(tokens)
        doc_tokens.append(tokens2)

# %% [markdown]
# ### 稀疏矩陣

# %%
sparse_matrix = []

dir_path = './ctee_TMC'
for file in os.listdir(dir_path):
    file_path = os.path.join(dir_path,file)
    if os.path.isfile(file_path) and not file.startswith('.'):
        text = getText(file_path)
        tokens = getTokens(text)
        doc_to_term = []
        for t in all_tokens:
            if t in tokens:
                doc_to_term.append(1)
            else:
                doc_to_term.append(0)
        sparse_matrix.append(doc_to_term)

# %% [markdown]
# ### 共現矩陣

# %%
def co_occurrence_matrix(ls):
    global matrix
    length = len(ls)
    for i in range(length):
        for j in range(length):
            if i != j:
                matrix[[ls[i]], [ls[j]]] += 1

# %%
dimension = len(all_tokens)
matrix = np.matrix([[0] * dimension] * dimension)

dt = Dictionary(doc_tokens).token2id
doc_token_ids = [[dt[word] for word in words] for words in doc_tokens]

for ids in doc_token_ids:
    co_occurrence_matrix(ids)

# %%
print(dt)
# Out:
# {',': 0, '000': 1, '|': 2, '上': 3, '世代': 4, '今日焦點': 5, '代工': 6, '億元': 7, '先進': 8, '創新': 9, '可望': 10, '台積': 11, '台積電': 12, '奈米': 13, '工商時報': 14, '布局': 15, '技術': 16, '持續': 17, '支援': 18, '產能': 19, '科技': 20, '脈動': 21, '製程': 22, '資金': 23, '電將': 24, '領先': 25, '龍頭': 26, '11月': 27, '個股': 28, '出貨': 29, '創下': 30, '受惠': 31, '合併': 32, '單季': 33, '大廠': 34, '新高': 35, '晶圓': 36, '機會': 37, '歷史': 38, '法人': 39, '營收': 40, '營收達': 41, '產業': 42, '目標': 43, '第四季': 44, '紀錄': 45, '蘋果': 46, '處理器': 47, '達': 48, '量': 49, '順利': 50, '高': 51, '今': 52, '台灣': 53, '張': 54, '張忠謀': 55, '營運': 56, '看': 57, '董事長': 58, '說': 59, '10': 60, '不': 61, '仍': 62, '供應鏈': 63, '億': 64, '公司': 65, '卻': 66, '積電': 67, '員工': 68, '報導': 69, '大陸': 70, '好': 71, '近期': 72, '都': 73, '(': 74, ')': 75, '2330': 76, 'ADR': 77, '元': 78, '前': 79, '台股': 80, '年': 81, '股價': 82, '中': 83, '兌': 84, '匯率': 85, '去年': 86, '大關': 87, '季': 88, '已': 89, '市場': 90, '平均': 91, '影響': 92, '新台幣': 93, '昨': 94, '會': 95, '月': 96, '法': 97, '約': 98, '美元匯率': 99, '表現': 100, '電在': 101, '預估': 102, '首季': 103, '％': 104, '2017': 105, '去年同期': 106, '增': 107, '增加': 108, '300': 109, '台': 110, '大': 111, '排名': 112, '跌破': 113, '鴻海': 114, '價值': 115, '億美元': 116, '半導體': 117, '國際': 118, '外資': 119, '市值': 120, '成': 121, '投資人': 122, '指出': 123, '比重': 124, '英特爾': 125, '超越': 126, '近': 127, '21': 128, '30': 129, '兆元': 130, '再創新高': 131, '加權指數': 132, '大漲': 133, '投資': 134, '獲利': 135, '貢獻': 136, '點': 137, '台幣': 138, '日': 139, '13': 140, '劉德音': 141, '升值': 142, '執行長': 143, '美國': 144, '說明會': 145, '財務': 146, '預期': 147, '魏哲家': 148, '2020年': 149, 'HPC': 150, '下修': 151, '人工智慧': 152, '仍將': 153, '優於': 154, '動能': 155, '占': 156, '將在': 157, '庫存': 158, '成長': 159, '提升': 160, '晶片': 161, '最': 162, '看好': 163, '運算': 164, '今早': 165,