# %%
from selenium import webdriver
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('C:\\Users\\USER\\github\\HW1--data-mining\\Script\\chromedriver')
# In[3]:

# %%
#### use to check is there any etf we have never download yet



filename = "C:\\Users\\USER\\github\\HW1--data-mining\\Script\\Emerging_Markets_ETF_List.csv"
df = pd.read_csv(filename)
passlist = []
for symbol in df['Symbol']:
    print(symbol)
    url = 'https://www.invesco.com/portal/site/us/financial-professional/etfs/product-detail?productId=' + symbol
    driver.get(url)
    element = driver.find_element_by_id('risk-disclosure')
    text = element.find_element_by_tag_name('div').text
    if "No results found." in text: 
        print("===> skip")
    else:
        print("===> download")
        #element = driver.find_element_by_id("downloadNavHistory")
        #element.click()
        passlist.append(symbol)
# Out:
# ADRE
# ===> download
# EEM
# ===> skip
# VWO
# ===> skip
# EEB
# ===> download
# SPEM
# ===> skip
# DEM
# ===> skip
# PXH
# ===> download
# DGS
# ===> skip
# EUM
# ===> skip
# EEV
# ===> skip
# BKF
# ===> skip
# PIE
# ===> download
# EWX
# ===> skip
# PXR
# ===> skip
# EDC
# ===> skip
# EDZ
# ===> skip
# EET
# ===> skip
# EMIF
# ===> skip
# SCHE
# ===> skip
# BICK
# ===> skip
# EWEM
# ===> download
# EDIV
# ===> skip
# FEM
# ===> skip
# DBEM
# ===> skip
# HILO
# ===> skip
# EEMS
# ===> skip
# EELV
# ===> download
# FEMS
# ===> skip
# DVYE
# ===> skip
# EEMO
# ===> download
# BBRC
# ===> skip
# TLTE
# ===> skip
# IEMG
# ===> skip
# DGRE
# ===> skip
# FNDE
# ===> skip
# EMCG
# ===> skip
# EMFM
# ===> skip
# EDOG
# ===> skip
# QEMM
# ===> skip
# HEEM
# ===> skip
# EMQQ
# ===> skip
# XSOE
# ===> skip
# JPEM
# ===> skip
# ROAM
# ===> skip
# SDEM
# ===> skip
# XCEM
# ===> skip
# GEM
# ===> skip
# TLEH
# ===> skip
# EMGF
# ===> skip
# EDBI
# ===> skip

# %%
i = 0
for symbol in df ['Symbol'] :
    if symbol in passlist :
        a = df.drop ([i] , inplace = True)
        print (a)
    i += 1
df.reset_index(inplace = True)

for i in range (len (df ['Symbol'])) :
    print (df ['Symbol'] [i] in passlist)

df.drop(['index'],inplace=True,axis=1)

df.to_csv('C:\\Users\\USER\\github\\HW1--data-mining\\ETF_data_set\\ETF_removefist7.csv')
# Out:
# None
# None
# None
# None
# None
# None
# None
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
